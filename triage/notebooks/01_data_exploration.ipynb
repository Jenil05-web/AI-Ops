# %% [markdown]
# ## Data Loading & Cleaning Phase :

# %%
import pandas as pd
import os
data_dir = '../data/raw'
files = ['dataset-tickets-multi-lang-4-20k.csv', 'dataset-tickets-multi-lang3-4k.csv', 'aa_dataset-tickets-multi-lang-5-2-50-version.csv']
df_temp = [pd.read_csv(os.path.join(data_dir, f)) for f in files]
df = pd.concat(df_temp, ignore_index=True)

## We loaded the csv file and we will process it according to our needs ( by removing certain unecessary things basically cleaning it to need and then saving it )

# %%
print(df.shape)
# Out:
# (52587, 18)

# %%
print(df.columns.tolist())
df.isnull().sum()
df['language'].value_counts()   # if this column exists
# Out:
# ['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8', 'business_type', 'tag_9', 'version']
# language
# en    29652
# de    21174
# es      812
# fr      476
# pt      473
# Name: count, dtype: int64

# %%
df = df[df['language'] == 'en']
print(df.shape)
# Out:
# (29652, 18)

# %%
df['type'].value_counts()
# Out:
# priority
# medium    12127
# high      11512
# low        6013
# Name: count, dtype: int64

# %%
df['queue'].value_counts()
# Out:
# queue
# Technical Support                  8617
# Product Support                    5540
# Customer Service                   4482
# IT Support                         3500
# Billing and Payments               3017
# Returns and Exchanges              1467
# Service Outages and Maintenance    1157
# Sales and Pre-Sales                 885
# Human Resources                     568
# General Inquiry                     419
# Name: count, dtype: int64

# %%
df['priority'].value_counts()
# Out:
# priority
# medium    12127
# high      11512
# low        6013
# Name: count, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Incident    11803
# Request      8537
# Problem      6163
# Change       3149
# Name: count, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
for q, group in df.groupby('queue'):
    print(f"\n=== {q} ===")
    print(group['body'].sample(1, random_state=1).values[0])
# Out:
# === Billing and Payments ===
# Hello Customer Support, I am reaching out to inquire about the billing features of the SaaS project management tool. Could you provide information on the available plans, payment options, and any discounts that may be offered? I am particularly interested in learning about the scalability of the tool and how it can adapt to growing business needs. Additionally, I would appreciate details on the level of support provided and the security measures in place to protect user data. Thank you for your time, and I look forward to hearing back soon.
#
# === Customer Service ===
# Customer Support, seeking information on integrating Smart-Tracker project management tools. Could provide details on the process? Would greatly appreciate any guidance or documentation you can provide. Specifically, I would like to know which tools are compatible with Smart-Tracker and the steps to integrate them. I believe that integrating Smart-Tracker tools would help streamline my project management workflow. Thank you for your assistance, and I look forward to hearing from you soon. Please let me know if you need any further information.
#
# === General Inquiry ===
# Customer Support, could you share specifics on how data analytics improves investment optimization services? I would greatly appreciate detailed information on the tools and techniques used to analyze data and make well-informed investment decisions. Moreover, I am interested in understanding how data analytics aids in identifying trends and patterns in the market, and how it contributes to the overall investment strategy. Thank you for your time and assistance. I look forward to your reply.
#
# === Human Resources ===
# Customer Support, reaching out to inquire about securing medical data within the hospital's infrastructure. Currently using SAP ERP and SQL Server to manage patient records and sensitive information. Could provide more details to ensure the confidentiality, integrity, and availability of the data? Concerned about potential security breaches and want to take proactive measures to protect patients' information. Specifically, would like to know about encryption methods, access controls, and auditing procedures.
#
# === IT Support ===
# I am encountering connectivity issues while performing video editing tasks, which might be related to my network setup. Despite attempting to restart my router and verifying my connections, the problem continues to occur. I would be very grateful if you could offer assistance to fix this. Kindly inform me of any further actions I should undertake or any additional information you might require from me. I am willing to share any necessary details or arrange a time for more in-depth troubleshooting. I appreciate your time and assistance and look forward to your prompt response. Thank you.
#
# === Product Support ===
# I am seeking guidance on optimizing data analytics strategies using MySQL 8.0 to enhance investment decision-making. Can you provide insights on how to leverage MySQL 8.0's features to improve data-driven decision making? I would greatly appreciate any tips or practices you can share. Specifically, I am interested in learning about query optimization, indexing, and data visualization techniques. I look forward to your assistance and am available to discuss further at your convenience.
#
# === Returns and Exchanges ===
# experienced unforeseen volatility in investment performance despite extensive data analysis. might be due to software incompatibility or inaccurate data integration. reviewed data inputs and tested multiple analytics tools to address the problem.
#
# === Sales and Pre-Sales ===
# Customer support has been contacted to inquire about integrating the Zoho Books project management SaaS platform. Could you furnish detailed documentation and guidance on how to achieve this integration? We would appreciate information on the steps involved, the credentials required, and any potential limitations. Since this integration is vital to our business operations, we look forward to your prompt response. Please let us know if there are additional resources or support options available to facilitate a smooth integration process.
#
# === Service Outages and Maintenance ===
# There is a performance decline in the system, which is affecting data analytics. The cause might be due to server overload during peak usage. After restarting the servers and clearing the cache, the issues still persist. Assistance is required to resolve this matter.
#
# === Technical Support ===
# Dear Support Team, <br><br>I am contacting you to inform you about a malfunction in our digital campaigns which were unable to start because of problems with Zapier and Express.js configurations. Despite our attempts to fix it, we haven't succeeded. <br><br>Here is a brief account of the issue: <br>**Situation:** Digital campaigns did not launch.<br>**Cause:** Configuration problems with Zapier and Express.js.<br>**Actions Taken:** Restarted the servers and verified API connections.<br><br>Even after these actions, the issue remains unresolved. Could you please look into this and offer a solution? <br><br>If you require more details, please let me know. I can be reached via this email or phone. <br><br>I appreciate your quick response to this situation. I am hoping for a prompt resolution. <br><br>Best regards, <br>[Your Name]

# %%
df.isnull().sum()
# Out:
# subject           3810
# body                 2
# answer               6
# type                 0
# queue                0
# priority             0
# language             0
# tag_1                0
# tag_2               16
# tag_3              113
# tag_4             2584
# tag_5            12173
# tag_6            20993
# tag_7            25589
# tag_8            27937
# business_type    28261
# tag_9            29652
# version          13314
# dtype: int64

# %%
df['queue'].value_counts()
# Out:
# queue
# Technical Support                  8617
# Product Support                    5540
# Customer Service                   4482
# IT Support                         3500
# Billing and Payments               3017
# Returns and Exchanges              1467
# Service Outages and Maintenance    1157
# Sales and Pre-Sales                 885
# Human Resources                     568
# General Inquiry                     419
# Name: count, dtype: int64

# %%
df['body'].str.len().describe()
# Out:
# count    29650.000000
# mean       386.158078
# std        231.028312
# min          4.000000
# 25%        209.000000
# 50%        372.000000
# 75%        539.000000
# max       2466.000000
# Name: body, dtype: float64

# %%
df.duplicated(subset='body').sum()
# Out:
# np.int64(4596)

# %%
pd.set_option('display.max_colwidth', None)
df[['subject','body','answer']].dropna().sample(3, random_state=1)
# Out:
#                                                               subject  \
# 15743    Strategies for Enhancing Tech Product Brand Growth Digitally
# 18670  Inquiry on Zapier Integrations with Investment Analytics Tools
# 10285                 Procedures for Safeguarding Medical Information
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 body  \
# 15743                                                                                                                                                                                                                                                                                                                                                                                                           I am contacting you to seek guidance on efficient digital strategies that can aid in the growth of a tech product brand. Would you be able to share any recommendations or insights?
# 18670  I am contacting you to seek information regarding the integrations available between Zapier and various investment analytics tools. Could you kindly furnish me with a list of the tools that are currently supported? I am especially interested in knowing about the integrations that facilitate automated data synchronization and workflow optimization. Furthermore, it would be greatly helpful if you could share any details about the setup and configuration process for these integrations. Thank you for your time and assistance in this matter. I eagerly await your response.
# 10285                                                                                                                                                                                                                                                                                                                                                                   I would like to know about the precautions your hospital takes to ensure the confidentiality of medical data within its IT infrastructure. Could you elaborate on the steps you have put in place to safeguard patient data?
#
#                                                                                                                                                                                                                                                                                                                                                                                                            answer
# 15743  Certainly, I can assist you with digital strategies to enhance the growth of your tech product brand. We could explore avenues such as social media marketing, content creation, and influencer collaborations. For personalized recommendations, could you provide details on your existing brand strategy and objectives? If convenient, we could arrange a call at <tel_num> to delve deeper into this.
# 18670                                                                                                                                                                                                                                                                                                                             I will send you a list of supported investment analytics tools via reply email.
# 10285                                          Patient data security is a top priority for us. Our hospital has put in place comprehensive security protocols, such as encryption and access controls, to ensure the protection of patient information. I will send you a detailed document that outlines our security procedures. If you wish to discuss this further, I can arrange a call at your convenience.

# %%
df = df.drop(columns=['tag_1','tag_2','tag_3','tag_4','tag_5','tag_6','tag_7','tag_8','tag_9','business_type','version','language'])
# drop unnecessary columns

# %%
df = df.dropna(subset=['subject','body','answer']) 
# drop missing things

# %%
df = df.drop_duplicates(subset='body')
# drop duplicate bodies

# %%
df['text_input'] = df['subject'] + " " + df['body']
#Combine subject + body for classifier input

# %%
from triage.data.cleaning import clean_pipeline, save_processed_data

df = clean_pipeline()
save_processed_data(df)
df.shape
# Out:
# (22053, 7)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (22053, 7)
# subject       0
# body          0
# answer        0
# type          0
# queue         0
# priority      0
# text_input    0
# dtype: int64

# %%
df.to_csv(r'C:\Users\jenil\OneDrive\Desktop\Machine learning\AI-Ops\triage\data\processed/tickets_clean.csv')

# %% [markdown]
# THINGS I PERFORMED IN THIS NOTEBOOK :
#
#
# Explored raw dataset — loaded and merged 3 CSV files (~29,650 English tickets), checked shape, nulls, and class balance across type, queue, and priority.
#
# Validated label quality — read actual ticket text against queue labels to confirm real signal exists (after an earlier dataset attempt turned out to have synthetic, disconnected labels).
#
# Dropped unusable columns — removed sparse tag columns, business_type, version, and non-English rows.
#
# Cleaned text data — removed rows with missing subject/body/answer, dropped ~4,596 duplicate ticket bodies, stripped HTML tags and placeholder tokens (e.g. <br>, <tel_num>).
#
# Engineered classifier input & saved output — combined subject + body into text_input, confirmed answer column as a valid RAG knowledge source, saved final clean dataset (22,053 rows, zero nulls) to data/processed/tickets_clean.csv.
